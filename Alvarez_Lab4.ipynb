# %% [markdown]
# <h2><b>Linear Algebra for CpE<i>

# %% [markdown]
# <h2><b>Laboratory 4: Vector Operations<i>

# %% [markdown]
# <h5>Coded and Submitted by:<i>
# <h5>Alvarez, Lee Andrei D.<i>
# <h5>58011<i>

# %% [markdown]
# <h5>Task 1<i>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from numpy.linalg import norm
# %matplotlib inline

# %%
vec1 = np.array([2,4,3,7])
vec2 = np.array([6,2,7,5])
vec3 = np.array([8,5,2,1])
vec4 = np.array([3,5,8,6])
vec5 = np.array([2,4,6,8])
vec6 = np.array([1,3,5,7])

# %%
v1 = norm(vec1)
v2 = norm(vec2)
v3 = norm(vec3)
v4 = norm(vec4)
v5 = norm(vec5)
v6 = norm(vec6)

v_1 = np.linalg.norm(vec1)
v_2 = np.linalg.norm(vec2)
v_3 = np.linalg.norm(vec3)
v_4 = np.linalg.norm(vec4)
v_5 = np.linalg.norm(vec5)
v_6 = np.linalg.norm(vec6)

print('Without using Numpy:', '\n',v1,'\n',v2,'\n',v3,'\n',v4,'\n',v5, '\nUsing Numpy:', '\n',v_1,'\n',v_2,'\n',v_3,'\n',v_4,'\n',v_5,)
# Out:
# Without using Numpy:
#  8.831760866327848
#  10.677078252031311
#  9.695359714832659
#  11.575836902790225
#  10.954451150103322
# Using Numpy:
#  8.831760866327848
#  10.677078252031311
#  9.695359714832659
#  11.575836902790225
#  10.954451150103322

# %% [markdown]
# <h5>Task 2<i>

# %%
a = np.array([2,4,3,7,6])
b = np.array([6,2,7,5,3])
c = np.array([8,5,2,1,7])
d = np.array([3,5,8,6,9])
e = np.array([2,4,6,8,1])
f = np.array([1,3,5,7,2])
g = np.array([7,3,5,8,2])
h = np.array([6,3,4,8,5])
i = np.array([1,2,5,7,9])
j = np.array([3,2,4,1,6])

# %%
Set1 = a.dot(b)
Set2 = c.dot(d)
Set3 = e.dot(f)
Set4 = g.dot(h)
Set5 = i.dot(j)

Set_1 = np.inner(a,b)
Set_2 = np.inner(c,d)
Set_3 = np.inner(e,f)
Set_4 = np.inner(g,h)
Set_5 = np.inner(i,j)

print('Without using Numpy:', '\n',Set1,'\n',Set2,'\n',Set3,'\n',Set4,'\n',Set5, '\nUsing Numpy:', '\n',Set_1,'\n',Set_2,'\n',Set_3,'\n',Set_4,'\n',Set_5)
# Out:
# Without using Numpy:
#  94
#  134
#  102
#  145
#  88
# Using Numpy:
#  94
#  134
#  102
#  145
#  88

# %% [markdown]
# <h5>Task 3<i>

# %% [markdown]
# $$ $$$$A = \begin{bmatrix}-0.4\\0.3\\-0.6\end{bmatrix}, B = \begin{bmatrix}-0.2\\0.2\\1\end{bmatrix}, C = \begin{bmatrix}0.2\\0.1\\-0.5\end{bmatrix}$$

# %%
A = np.array([-0.4,0.3,-0.6])
B = np.array([-0.2,0.2,1])
C = np.array([0.2,0.1,-0.5])

X = ((A**2+B**2+C**2)@(A*(B+A*B)/C))*(np.absolute(A))+(np.absolute(B))
Y = A**2+B**2
Z = (A)
X = (A@A + B@B + C@C)
X1 = (A*(B+A*B)/C)
X2 = (np.linalg.norm(A+B+C))
Ans = X*X1*X2

np.array(Ans)
# Out:
# array([0.34769805, 1.13001866, 0.6953961 ])

# %%
plot = plt.figure()
a1 = plot.gca(projection = '3d')

a1.quiver(0,0,0, Ans[0], Ans[1], Ans[2], color = 'red')
a1.set_xlim([0,3])
a1.set_ylim([0,3])
a1.set_zlim([0,3])
plt.show()
